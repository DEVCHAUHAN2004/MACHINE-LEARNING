# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load dataset
data = pd.read_csv("student.csv")

# Input and Output
X = data[["Hours"]]
y = data["Score"]

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Prediction on training data
pred_score = model.predict(X)

# Error calculation
mae = mean_absolute_error(y, pred_score)
mse = mean_squared_error(y, pred_score)
rmse = np.sqrt(mse)

print("MAE :", mae)
print("MSE :", mse)
print("RMSE:", rmse)

# Predict score for 7 hours
new_pred = model.predict([[7]])
print("Predicted Score:", new_pred)
# Out:
# MAE : 1.0800000000000018
# MSE : 1.3296969696969712
# RMSE: 1.1531248716843163
# Predicted Score: [84.30909091]
# c:\Users\asus\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
